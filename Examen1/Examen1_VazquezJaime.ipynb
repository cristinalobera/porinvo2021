# %% [markdown]
# # Examen 1 - Portafolios de inversión - O2018. Tipo 3.
#
# <img style="float: right; margin: 0px 0px 15px 15px;" src="data:image/jpeg;base64,..." width="600px" height="400px" />
#
# **Resumen.**
# > Este examen pretende evaluar los conocimientos que hemos adquirido a lo largo de los dos primeros módulos.
#
# > El examen consta de dos partes.
# 1. La primera es meramente teórica, y los cálculos que puede llegar a involucrar son bastante sencillos. En esta parte, las preguntas son de selección múltiple con justificación, es decir, debes elegir la(s) respuesta(s) correcta(s) y decir porqué la seleccionaste.
# 2. La segunda parte es práctica, como lo que se ha venido haciendo en las tareas. En esta parte deberás importar un archivo donde se encuentran reportados los precios ajustados en el cierre de dos compañías en una base diaria, deberás caracterizar los rendimientos y con base en ello construir fronteras media-varianza bajo ciertas condiciones. Finalmente deberás concluir de los resultados.
#
# **Criterio de revisión.**
# > Primera parte: tiene un valor del 40% del examen. Cada pregunta tiene un valor del 8%, de los cuales 4% corresponde a la selección y el otro 4% corresponde a la justificación. Si la pregunta corresponde a un cálculo numérico, la justificación es en sí las operaciones resueltas para obtener el resultado en el notebook.
#
# > Segunda parte: tiene un valor del 60% del examen. Se te calificará de acuerdo a los resultados finales que reportes, basados en tu análisis.
#
# **Antes de comenzar.**
# > Por favor, nombrar este archivo *Examen1_ApellidoNombre*, sin acentos y sin espacios; por ejemplo, en mi caso el archivo se llamaría *Tarea5_JimenezEsteban*. Resolver todos los puntos en dicho archivo y subir a moodle.
# ___

# %% [markdown]
# ## I. Primera parte (40%)

# %% [markdown]
# **Pregunta 1.** ¿Cuál se utiliza comúnmente como medida de riesgo en los rendimientos?
#
# A. Rendimiento esperado.
#
# B. Inflación.
#
# C. Desviación estándar.
#
# D. Rendimiento medio geométrico.

# %% [markdown]
# La respuesta correcta es (4%): C

# %% [markdown]
# Justificación (4%):  la volatilidad es una buena medida de riesgo, siempre y cuando tengamos distribuciones simétricas y sin mucho riesgo de eventos extremos.

# %% [markdown]
# **Pregunta 2.** Si los rendimientos anuales pasados de una inversión fueron reportados como 12% al final del primer año, -10% al final del segundo año y 5% al final del tercer año, ¿cuál fue el rendimiento total en los tres años de la inversión?
#
# A. 4.45%
#
# B. 4.80%
#
# C. 5.84%
#
# D. 6.32%

# %% [markdown]
# La respuesta correcta es (4%):

# %%
# La justificación a esta pregunta son los cálculos necesarios para llegar al resultado (4%)

# %% [markdown]
# **Pregunta 3.** Considere la siguiente distribución de rendimientos de los activos A, B y C:
#
#
# | Probabilidad     | Rendimiento A       | Rendimiento B         | Rendimiento C         |
# | ---------------- | ------------------  | -------------------   | ------------------    |
# | 0.3              | -0.20               | -0.05                 | 0.05                  |
# | 0.4              | 0.05                | 0.10                  | 0.03                  |
# | 30%              | 0.40                | 0.15                  | 0.02                  |
#
#
# Calcule el rendimiento esperado de un portafolio compuesto 40% por el activo A, 40% por el activo B y 20% por el activo C.
#
# A. 6.66%
#
# B. 5.05%
#
# C. 8.93%
#
# D. 7.00%

# %% [markdown]
# La respuesta correcta es (4%): A

# %%
import numpy as np
import pandas as pd

# %%
# La justificación a esta pregunta son los cálculos necesarios para llegar al resultado (4%)
# Creamos tabla
tabla2 = pd.DataFrame(columns=['prob', 'RA', 'RB', 'RC'])
tabla2['prob']=[0.3,0.4,0.3]
tabla2['RA']=[-0.20,0.05,0.40]
tabla2['RB']=[-0.05,0.10,0.15]
tabla2['RC']=[0.05,0.03,0.02]
tabla2['PortABC'] = 0.4*tabla2['RA']+0.4*tabla2['RB']+0.2*tabla2['RC']


tabla2.round(2)
# Out:
#    prob    RA    RB    RC  PortABC
# 0   0.3 -0.20 -0.05  0.05    -0.09
# 1   0.4  0.05  0.10  0.03     0.07
# 2   0.3  0.40  0.15  0.02     0.22

# %%
ErPortTP = np.sum(tabla2.prob*tabla2.PortABC)
ErPortTP
# Out:
# 0.0666

# %% [markdown]
# **Pregunta 4.** ¿Cuál de las siguientes proposiciones es falsa acerca de la frontera de mínima varianza?
#
# A. La parte de abajo de la frontera de mínima varianza es la frontera eficiente.
#
# B. Para dos activos, la frontera de mínima varianza es simplemente todas las posibles combinaciones de portafolios entre los dos activos.
#
# C. La frontera de mínima varianza se expande a medida que agregamos más activos al portafolio.
#
# D. La frontera de mínima varianza es el lugar geométrico en el espacio de rendimiento esperado contra volatilidad que tiene mínima varianza para cada rendmiento esperado.

# %% [markdown]
# La respuesta correcta es (4%): A

# %% [markdown]
# Justificación (4%):

# %% [markdown]
# **Pregunta 5.** ¿Cuáles de las siguientes proposiciones son correctas?
#
# A. En el espacio de rendimiento esperado contra volatilidad, puede encontrarse un portafolio más a la izquierda que el portafolio de mínima varianza.
#
# B. La frontera eficiente son todos los portafolios que yacen en la parte superior de la frontera de mínima varianza, a partir de portafolio de mínima varianza.
#
# C. La diversificación remueve el riesgo idiosincrático más no el riesgo sistemático.
#
# D. El riesgo sistemático tiene que ver con el riesgo que afecta a cada activo por razones específicas.

# %% [markdown]
# La(s) respuesta(s) correcta(s) es(son) (4%): B Y C

# %% [markdown]
# Justificación (4%): no remueve el riesgo sistemático ya que es una variable que no se puede predecir a ciencia cierta

# %% [markdown]
# ___
# ## II. Segunda parte (60%)

# %% [markdown]
# **Punto 1 (20%).** En el archivo `data.csv` se encuentran reportados los precios mensuales ajustados en el cierre de los activos de Microsoft, Grupo Financiero Banorte, Grupo Financiero Inbursa, Cemex y Grupo Carso.
#
# 1. Importar los precios de *Microsoft (MSFT) y de Cemex (CEMEXCPO.MX)* en un DataFrame indizado por fecha. Mostrar la gráfica de estos precios (5%).
# 2. Obtener un DataFrame con los rendimientos porcentuales mensuales para estos activos. Mostrar la gráfica de rendimientos (5%).
# 3. Reportar en un DataFrame el rendimiento esperado mensual y la volatilidad mensual para cada uno de estos activos (5%).
# 4. Calcular las matrices de varianza-covarianza (base mensual) y de correlación (base mensual) para estos activos (5%).

# %%
import pandas as pd

# %%
file_name='data.csv'
tabla = pd.read_csv(file_name)
tabla
# Out:
#           Date        MSFT  GFNORTEO.MX  GFINBURO.MX  CEMEXCPO.MX  GCARSOA1.MX
# 0   2012-01-01   24.824419    45.010750    24.650887     6.978480    36.289150
# 1   2012-02-01   26.682266    45.062740    23.193285     7.776690    36.748508
# 2   2012-03-01   27.297937    49.438301    24.339197     8.137080    36.840378
# 3   2012-04-01   27.094851    54.610775    26.264334     7.742550    40.423363
# 4   2012-05-01   24.700151    55.732189    27.144396     6.616510    36.766895
# 5   2012-06-01   26.054655    60.102745    27.807650     7.380910    40.158829
# 6   2012-07-01   25.100708    62.081757    32.119267     7.627480    42.535812
# 7   2012-08-01   26.250557    58.646809    33.157764     8.013790    40.149578
# 8   2012-09-01   25.515629    63.433067    33.398846     8.802840    40.824749
# 9   2012-10-01   24.469625    63.424347    32.332535     9.756270    43.830654
# 10  2012-11-01   22.823465    64.775208    33.241215     9.468600    49.146179
# 11  2012-12-01   23.088800    72.928925    36.356709    10.438500    58.243526
# 12  2013-01-01   23.728479    76.616867    33.037228    11.400100    57.479992
# 13  2013-02-01   24.031023    83.052200    33.398846    11.276800    57.722084
# 14  2013-03-01   24.935972    86.414932    33.408115    12.353600    64.109779
# 15  2013-04-01   28.849375    80.179886    32.990868    11.702300    64.538101
# 16  2013-05-01   30.418219    71.728737    27.186401    12.762200    62.508198
# 17  2013-06-01   30.315554    67.315315    26.809084    11.762100    57.166489
# 18  2013-07-01   27.945776    71.202271    28.054924    12.582700    59.505928
# 19  2013-08-01   29.314980    73.423965    26.677938    12.967400    61.742432
# 20  2013-09-01   29.415483    71.876152    28.092398    12.531400    65.429398
# 21  2013-10-01   31.298151    73.239258    31.483341    11.847600    65.682037
# 22  2013-11-01   33.702305    79.002754    32.429432    12.351900    65.761520
# 23  2013-12-01   33.316677    80.536598    34.593269    13.112700    65.328804
# 24  2014-01-01   33.699623    75.070450    31.239792    14.129900    65.705070
# 25  2014-02-01   34.118206    76.669014    29.731665    14.822300    64.971367
# 26  2014-03-01   36.778709    78.273140    31.473970    14.104300    64.613914
# 27  2014-04-01   36.249313    77.292816    31.342829    14.872900    62.553875
# 28  2014-05-01   36.733837    83.054550    33.000832    14.721800    62.770226
# 29  2014-06-01   37.679714    82.884827    36.441296    15.273000    63.845295
# ..         ...         ...          ...          ...          ...          ...
# 52  2016-05-01   50.171154    88.107109    29.481119    11.278800    75.151665
# 53  2016-06-01   48.777630    93.593826    30.090748    10.865400    75.522438
# 54  2016-07-01   54.030018    94.195656    29.246264    13.740400    74.099861
# 55  2016-08-01   54.773552    92.838081    31.837952    14.971200    74.148247
# 56  2016-09-01   55.249226    94.810249    29.702480    14.769200    74.980507
# 57  2016-10-01   57.474541   103.789619    29.770428    15.730800    79.838562
# 58  2016-11-01   57.800663    91.956993    27.236980    15.394200    74.036072
# 59  2016-12-01   60.006588    95.388351    30.449896    15.903800    81.664452
# 60  2017-01-01   62.430424    93.197121    30.003387    19.260000    81.537964
# 61  2017-02-01   61.783424    93.103882    27.838795    16.355801    82.948822
# 62  2017-03-01   63.984440   100.386223    30.119869    16.298100    83.639648
# 63  2017-04-01   66.510399   102.861603    30.857578    16.653900    84.194267
# 64  2017-05-01   67.851097   101.426544    29.993681    15.420000    76.351830
# 65  2017-06-01   67.350868   108.941719    30.517040    17.049999    74.366898
# 66  2017-07-01   71.034500   114.231277    31.668810    17.200001    72.656860
# 67  2017-08-01   73.057076   118.006081    29.434177    16.709999    70.709290
# 68  2017-09-01   73.171272   121.548592    32.791054    16.549999    70.249321
# 69  2017-10-01   81.707436   110.127396    32.436661    15.580000    60.854034
# 70  2017-11-01   82.679909   110.524239    32.407127    14.260000    58.084385
# 71  2017-12-01   84.447639   104.368408    31.619591    14.700000    64.469643
# 72  2018-01-01   93.796707   103.923172    33.302952    15.070000    65.085251
# 73  2018-02-01   92.572540   109.527306    29.650751    12.450000    65.720711
# 74  2018-03-01   90.527733   107.562462    29.621218    12.030000    63.576023
# 75  2018-04-01   92.759430   113.263382    30.674547    11.700000    66.723549
# 76  2018-05-01   98.036163   102.790726    27.731131    11.860000    61.729210
# 77  2018-06-01   98.231979   113.311775    27.799999    13.060000    66.574615
# 78  2018-07-01  105.673340   129.960007    30.700001    13.890000    77.510002
# 79  2018-08-01  111.899384   130.860001    30.360001    13.530000    70.699997
# 80  2018-09-01  114.370003   135.300003    29.360001    13.140000    62.070000
# 81  2018-10-01  115.610001   136.380005    29.719999    13.360000    62.310001
#
# [82 rows x 6 columns]

# %%
tabla = pd.read_csv(file_name, index_col='Date',usecols=['Date','MSFT', 'CEMEXCPO.MX'])
tabla
# Out:
#                   MSFT  CEMEXCPO.MX
# Date
# 2012-01-01   24.824419     6.978480
# 2012-02-01   26.682266     7.776690
# 2012-03-01   27.297937     8.137080
# 2012-04-01   27.094851     7.742550
# 2012-05-01   24.700151     6.616510
# 2012-06-01   26.054655     7.380910
# 2012-07-01   25.100708     7.627480
# 2012-08-01   26.250557     8.013790
# 2012-09-01   25.515629     8.802840
# 2012-10-01   24.469625     9.756270
# 2012-11-01   22.823465     9.468600
# 2012-12-01   23.088800    10.438500
# 2013-01-01   23.728479    11.400100
# 2013-02-01   24.031023    11.276800
# 2013-03-01   24.935972    12.353600
# 2013-04-01   28.849375    11.702300
# 2013-05-01   30.418219    12.762200
# 2013-06-01   30.315554    11.762100
# 2013-07-01   27.945776    12.582700
# 2013-08-01   29.314980    12.967400
# 2013-09-01   29.415483    12.531400
# 2013-10-01   31.298151    11.847600
# 2013-11-01   33.702305    12.351900
# 2013-12-01   33.316677    13.112700
# 2014-01-01   33.699623    14.129900
# 2014-02-01   34.118206    14.822300
# 2014-03-01   36.778709    14.104300
# 2014-04-01   36.249313    14.872900
# 2014-05-01   36.733837    14.721800
# 2014-06-01   37.679714    15.273000
# ...                ...          ...
# 2016-05-01   50.171154    11.278800
# 2016-06-01   48.777630    10.865400
# 2016-07-01   54.030018    13.740400
# 2016-08-01   54.773552    14.971200
# 2016-09-01   55.249226    14.769200
# 2016-10-01   57.474541    15.730800
# 2016-11-01   57.800663    15.394200
# 2016-12-01   60.006588    15.903800
# 2017-01-01   62.430424    19.260000
# 2017-02-01   61.783424    16.355801
# 2017-03-01   63.984440    16.298100
# 2017-04-01   66.510399    16.653900
# 2017-05-01   67.851097    15.420000
# 2017-06-01   67.350868    17.049999
# 2017-07-01   71.034500    17.200001
# 2017-08-01   73.057076    16.709999
# 2017-09-01   73.171272    16.549999
# 2017-10-01   81.707436    15.580000
# 2017-11-01   82.679909    14.260000
# 2017-12-01   84.447639    14.700000
# 2018-01-01   93.796707    15.070000
# 2018-02-01   92.572540    12.450000
# 2018-03-01   90.527733    12.030000
# 2018-04-01   92.759430    11.700000
# 2018-05-01   98.036163    11.860000
# 2018-06-01   98.231979    13.060000
# 2018-07-01  105.673340    13.890000
# 2018-08-01  111.899384    13.530000
# 2018-09-01  114.370003    13.140000
# 2018-10-01  115.610001    13.360000
#
# [82 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

tabla[['MSFT', 'CEMEXCPO.MX']].plot(figsize=(8,6));

# %%
tabla.shift()
# Out:
#                   MSFT  CEMEXCPO.MX
# Date
# 2012-01-01         NaN          NaN
# 2012-02-01   24.824419     6.978480
# 2012-03-01   26.682266     7.776690
# 2012-04-01   27.297937     8.137080
# 2012-05-01   27.094851     7.742550
# 2012-06-01   24.700151     6.616510
# 2012-07-01   26.054655     7.380910
# 2012-08-01   25.100708     7.627480
# 2012-09-01   26.250557     8.013790
# 2012-10-01   25.515629     8.802840
# 2012-11-01   24.469625     9.756270
# 2012-12-01   22.823465     9.468600
# 2013-01-01   23.088800    10.438500
# 2013-02-01   23.728479    11.400100
# 2013-03-01   24.031023    11.276800
# 2013-04-01   24.935972    12.353600
# 2013-05-01   28.849375    11.702300
# 2013-06-01   30.418219    12.762200
# 2013-07-01   30.315554    11.762100
# 2013-08-01   27.945776    12.582700
# 2013-09-01   29.314980    12.967400
# 2013-10-01   29.415483    12.531400
# 2013-11-01   31.298151    11.847600
# 2013-12-01   33.702305    12.351900
# 2014-01-01   33.316677    13.112700
# 2014-02-01   33.699623    14.129900
# 2014-03-01   34.118206    14.822300
# 2014-04-01   36.778709    14.104300
# 2014-05-01   36.249313    14.872900
# 2014-06-01   36.733837    14.721800
# ...                ...          ...
# 2016-05-01   47.208221    12.278800
# 2016-06-01   50.171154    11.278800
# 2016-07-01   48.777630    10.865400
# 2016-08-01   54.030018    13.740400
# 2016-09-01   54.773552    14.971200
# 2016-10-01   55.249226    14.769200
# 2016-11-01   57.474541    15.730800
# 2016-12-01   57.800663    15.394200
# 2017-01-01   60.006588    15.903800
# 2017-02-01   62.430424    19.260000
# 2017-03-01   61.783424    16.355801
# 2017-04-01   63.984440    16.298100
# 2017-05-01   66.510399    16.653900
# 2017-06-01   67.851097    15.420000
# 2017-07-01   67.350868    17.049999
# 2017-08-01   71.034500    17.200001
# 2017-09-01   73.057076    16.709999
# 2017-10-01   73.171272    16.549999
# 2017-11-01   81.707436    15.580000
# 2017-12-01   82.679909    14.260000
# 2018-01-01   84.447639    14.700000
# 2018-02-01   93.796707    15.070000
# 2018-03-01   92.572540    12.450000
# 2018-04-01   90.527733    12.030000
# 2018-05-01   92.759430    11.700000
# 2018-06-01   98.036163    11.860000
# 2018-07-01   98.231979    13.060000
# 2018-08-01  105.673340    13.890000
# 2018-09-01  111.899384    13.530000
# 2018-10-01  114.370003    13.140000
#
# [82 rows x 2 columns]

# %%
tabla_ret = ((tabla-tabla.shift())/tabla.shift()).dropna()
tabla_ret
# Out:
#                 MSFT  CEMEXCPO.MX
# Date
# 2012-02-01  0.074839     0.114382
# 2012-03-01  0.023074     0.046342
# 2012-04-01 -0.007440    -0.048485
# 2012-05-01 -0.088382    -0.145435
# 2012-06-01  0.054838     0.115529
# 2012-07-01 -0.036613     0.033406
# 2012-08-01  0.045809     0.050647
# 2012-09-01 -0.027997     0.098462
# 2012-10-01 -0.040995     0.108309
# 2012-11-01 -0.067274    -0.029486
# 2012-12-01  0.011626     0.102433
# 2013-01-01  0.027705     0.092121
# 2013-02-01  0.012750    -0.010816
# 2013-03-01  0.037658     0.095488
# 2013-04-01  0.156938    -0.052721
# 2013-05-01  0.054381     0.090572
# 2013-06-01 -0.003375    -0.078364
# 2013-07-01 -0.078170     0.069766
# 2013-08-01  0.048995     0.030574
# 2013-09-01  0.003428    -0.033623
# 2013-10-01  0.064003    -0.054567
# 2013-11-01  0.076815     0.042566
# 2013-12-01 -0.011442     0.061594
# 2014-01-01  0.011494     0.077574
# 2014-02-01  0.012421     0.049002
# 2014-03-01  0.077979    -0.048441
# 2014-04-01 -0.014394     0.054494
# 2014-05-01  0.013366    -0.010159
# 2014-06-01  0.025749     0.037441
# 2014-07-01  0.035012    -0.034924
# ...              ...          ...
# 2016-05-01  0.062763    -0.081441
# 2016-06-01 -0.027775    -0.036653
# 2016-07-01  0.107680     0.264601
# 2016-08-01  0.013761     0.089575
# 2016-09-01  0.008684    -0.013493
# 2016-10-01  0.040278     0.065108
# 2016-11-01  0.005674    -0.021398
# 2016-12-01  0.038164     0.033103
# 2017-01-01  0.040393     0.211031
# 2017-02-01 -0.010364    -0.150789
# 2017-03-01  0.035625    -0.003528
# 2017-04-01  0.039478     0.021831
# 2017-05-01  0.020158    -0.074091
# 2017-06-01 -0.007372     0.105707
# 2017-07-01  0.054693     0.008798
# 2017-08-01  0.028473    -0.028488
# 2017-09-01  0.001563    -0.009575
# 2017-10-01  0.116660    -0.058610
# 2017-11-01  0.011902    -0.084724
# 2017-12-01  0.021380     0.030856
# 2018-01-01  0.110708     0.025170
# 2018-02-01 -0.013051    -0.173855
# 2018-03-01 -0.022089    -0.033735
# 2018-04-01  0.024652    -0.027431
# 2018-05-01  0.056886     0.013675
# 2018-06-01  0.001997     0.101180
# 2018-07-01  0.075753     0.063553
# 2018-08-01  0.058918    -0.025918
# 2018-09-01  0.022079    -0.028825
# 2018-10-01  0.010842     0.016743
#
# [81 rows x 2 columns]

# %%
tabla_ret.plot(figsize=(8,6));

# %%
tabla_ret.mean()
# Out:
# MSFT           0.020767
# CEMEXCPO.MX    0.011820
# dtype: float64

# %%
tabla_ret.std()
# Out:
# MSFT           0.057559
# CEMEXCPO.MX    0.088485
# dtype: float64

# %%
tabla_ret_summ = pd.DataFrame(index=['Mean', 'Volatility'] ,columns =['MSFT','CEMEXCPO.MX'])
tabla_ret_summ.loc['Mean']=tabla_ret.mean()
tabla_ret_summ.loc['Volatility']=tabla_ret.std()
tabla_ret_summ
# Out:
#                  MSFT CEMEXCPO.MX
# Mean        0.0207666   0.0118196
# Volatility  0.0575586    0.088485

# %%
names = ['GFNORTEO.MX','GFINBURO.MX','CEMEXCPO.MX','GCARSOA1.MX','KIMBERA.MX','BIMBOA.MX','ALFAA.MX']
names
# Out:
# ['GFNORTEO.MX',
#  'GFINBURO.MX',
#  'CEMEXCPO.MX',
#  'GCARSOA1.MX',
#  'KIMBERA.MX',
#  'BIMBOA.MX',
#  'ALFAA.MX']

# %%
covmc = np.sum((tabla_ret_summ.MSFT[:1]-tabla_ret_summ.MSFT[1])*(tabla_ret_summ.CEMEXCPO[:1]-tabla_ret_summ.CEMEXCPO.[1]))
covmc
# Out:
#   File "<ipython-input-16-1cf06b0a5870>", line 1
#     covmc = np.sum((tabla_ret_summ.MSFT[:1]-tabla_ret_summ.MSFT[1])*(tabla_ret_summ.CEMEXCPO[:1]-tabla_ret_summ.CEMEXCPO.[1]))
#                                                                                                                          ^
# SyntaxError: invalid syntax

# %%
corrmc = covmc/(tabla_ret_sum.MSFT[1]*daily_ren_sum.CEMEXCPO.MX[1])

# %% [markdown]
# **Punto 2 (15%).** Usando los datos del punto anterior:
#
# 1. Construya la frontera de mínima varianza que representa las posibles combinaciones de portafolios que se pueden crear con los activos del primer punto. Reportar los rendimientos esperados y las volatilidades de estos portafolios en un DataFrame (8%).
# 2. Encontrar los pesos del portafolio de mínima varianza. ¿Cuáles son el rendimiento esperado y volatilidad del portafolio de mínima varianza? (7%).

# %%
import pandas as pd
import numpy as np

# %%
# Vector de w variando entre 0 y 1 con n pasos
w = np.linspace(0, 1, 100)
# Rendimientos esperados individuales
# Activo1: EU, Activo2:Japon
E1 = tabla_ret_summ['MSFT']['Mean']
E2 = tabla_ret_summ['CEMEXCPO.MX']['Mean']
# Volatilidades individuales
s1 = tabla_ret_summ['MSFT']['Volatility']
s2 = tabla_ret_summ['CEMEXCPO.MX']['Volatility']
# Correlacion
r12 = corrmc['MSFT']['CEMEXCPO.MX']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-124ba482bad9> in <module>
#       9 s2 = tabla_ret_summ['CEMEXCPO.MX']['Volatility']
#      10 # Correlacion
# ---> 11 r12 = corrmc['MSFT']['CEMEXCPO.MX']
#
# NameError: name 'corrmc' is not defined

# %%
portafolios2 = pd.DataFrame(index=w,columns=['Rend','Vol'])
portafolios2.index.name = 'w'
portafolios2.Rend = w*E1+(1-w)*E2
portafolios2.Vol = np.sqrt((w*s1)**2+((1-w)*s2)**2+2*w*(1-w)*r12*s1*s2)
portafolios2.round(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ef705e415bd8> in <module>
#       2 portafolios2.index.name = 'w'
#       3 portafolios2.Rend = w*E1+(1-w)*E2
# ----> 4 portafolios2.Vol = np.sqrt((w*s1)**2+((1-w)*s2)**2+2*w*(1-w)*r12*s1*s2)
#       5 portafolios2.round(4)
#
# NameError: name 'r12' is not defined

# %%
plt.figure(figsize=(8,6))
plt.plot(s1, E1, 'ro', ms = 10, label='MSFT')
plt.plot(s2, E2, 'bo', ms = 10, label='CEMEXCPO.MX')
plt.plot(portafolios2.Vol, portafolios2.Rend, 'k-', lw = 4, label='Portafolios')
plt.xlabel('Volatilidad ($\sigma$)')
plt.ylabel('Rendimiento esperado ($E[r]$)')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
import scipy.optimize as opt

# %%
def var2(w,s1,s2,s12):
    return (w*s1)**2+((1-w)*s2)**2+2*w*(1-w)*s12

# %%
# Dato inicial
w0 = 0
# Volatilidades individuales y covarianza
s1 = tabla_ret_summ['MSFT']['Volatilidad']
s2 = tabla_ret_summ['CEMEXCPO.MX']['Volatilidad']
s12 = corr['MSFT']['CEMEXCPO.MX']*s1*s2
# Cota de w
bnd = (0, 1)

# %%
min_var2 = opt.minimize(var2, w0, args=(s1,s2,s12), bounds=(bnd,))
min_var2

# %%
# Graficar el portafolio de varianza mínima
# sobre el mismo gráfico realizado anteriormente
plt.figure(figsize=(8,6))
plt.plot(s1, E1, 'ro', ms = 10, label='MSFT')
plt.plot(s2, E2, 'bo', ms = 10, label='CEMEXCPO.MX')
plt.plot(portafolios2.Vol, portafolios2.Rend, 'k-', lw = 4, label='Portafolios')
plt.plot(np.sqrt(min_var2.fun), min_var2.x*E1+(1-min_var2.x)*E2, '*m', ms=10, label='Port. Min. Var.')
#plt.plot(np.sqrt(var2(min_var2.x,s1,s2,s12)), min_var2.x*E1+(1-min_var2.x)*E2, '*m', ms=10, label='Port. Min. Var.')
plt.xlabel('Volatilidad ($\sigma$)')
plt.ylabel('Rendimiento esperado ($E[r]$)')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# **Punto 3 (15%).** En este punto se usarán los mismos activos con sus rendimientos esperados y volatilidades, solo que supondremos que el coeficiente de correlación entre sus rendimientos se supondrá de 0.5.
#
# 1. Nuevamente, construya la frontera de mínima varianza para estos dos activos con el nuevo supuesto de correlación. Reportar los rendimientos esperados y las volatilidades de estos portafolios en un DataFrame (8%).
# 2. Encontrar los pesos del portafolio de mínima varianza. ¿Cuáles son el rendimiento esperado y volatilidad del portafolio de mínima varianza? (7%).

# %%
# Vector de w variando entre 0 y 1 con n pasos
w = np.linspace(0, 1, 100)
# Rendimientos esperados individuales
# Activo1: EU, Activo2:Japon
E1 = tabla_ret_summ['MSFT']['Mean']
E2 = tabla_ret_summ['CEMEXCPO.MX']['Mean']
# Volatilidades individuales
s1 = tabla_ret_summ['MSFT']['Volatility']
s2 = tabla_ret_summ['CEMEXCPO.MX']['Volatility']
# Correlacion
r12 = corrmc['MSFT']['CEMEXCPO.MX']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-124ba482bad9> in <module>
#       9 s2 = tabla_ret_summ['CEMEXCPO.MX']['Volatility']
#      10 # Correlacion
# ---> 11 r12 = corrmc['MSFT']['CEMEXCPO.MX']
#
# NameError: name 'corrmc' is not defined

# %%
portafolios2 = pd.DataFrame(index=w,columns=['Rend','Vol'])
portafolios2.index.name = 'w'
portafolios2.Rend = w*E1+(1-w)*E2
portafolios2.Vol = np.sqrt((w*s1)**2+((1-w)*s2)**2+2*w*(1-w)*r12*s1*s2)
portafolios2.round(4)

# %%
plt.figure(figsize=(8,6))
plt.plot(s1, E1, 'ro', ms = 10, label='MSFT')
plt.plot(s2, E2, 'bo', ms = 10, label='CEMEXCPO.MX')
plt.plot(portafolios2.Vol, portafolios2.Rend, 'k-', lw = 4, label='Portafolios')
plt.xlabel('Volatilidad ($\sigma$)')
plt.ylabel('Rendimiento esperado ($E[r]$)')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
import scipy.optimize as opt

# %%
def var2(w,s1,s2,s12):
    return (w*s1)**2+((1-w)*s2)**2+2*w*(1-w)*s12

# %%
# Dato inicial
w0 = 0
# Volatilidades individuales y covarianza
s1 = tabla_ret_summ['MSFT']['Volatilidad']
s2 = tabla_ret_summ['CEMEXCPO.MX']['Volatilidad']
s12 = 0.5*s1*s2
# Cota de w
bnd = (0, 1)

# %%
min_var2 = opt.minimize(var2, w0, args=(s1,s2,s12), bounds=(bnd,))
min_var2

# %%
# Graficar el portafolio de varianza mínima
# sobre el mismo gráfico realizado anteriormente
plt.figure(figsize=(8,6))
plt.plot(s1, E1, 'ro', ms = 10, label='MSFT')
plt.plot(s2, E2, 'bo', ms = 10, label='CEMEXCPO.MX')
plt.plot(portafolios2.Vol, portafolios2.Rend, 'k-', lw = 4, label='Portafolios')
plt.plot(np.sqrt(min_var2.fun), min_var2.x*E1+(1-min_var2.x)*E2, '*m', ms=10, label='Port. Min. Var.')
#plt.plot(np.sqrt(var2(min_var2.x,s1,s2,s12)), min_var2.x*E1+(1-min_var2.x)*E2, '*m', ms=10, label='Port. Min. Var.')
plt.xlabel('Volatilidad ($\sigma$)')
plt.ylabel('Rendimiento esperado ($E[r]$)')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# **Punto 4 (10%).**
#
# 1. Usando sus respuestas para los puntos 2 y 3, grafique las dos fronteras encontradas en una sola gráfica, además de los puntos correspondientes a los activos individuales, donde el eje $x$ es la volatilidad y el eje $y$ el rendimiento esperado. Asegúrese de etiquetar todo y poner distintos colores para diferenciar los distintos elementos en su gráfico (5%).
# 2. Concluya acerca de la gráfica de las dos fronteras de mínima varianza. ¿Cuál provee más diversificación?, ¿cómo se diferencian?, ¿son diferentes los pesos de los dos portafolios de varianza mínima en cada caso?, ¿cómo puede explicar esta diferencia? (5%).

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Esteban Jiménez Rodríguez.
# </footer>
